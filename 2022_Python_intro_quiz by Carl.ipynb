# %% [markdown]
# # 练习题

# %% [markdown]
# 你可以修改下面的代码，让它输入一个数字，并输出它的 2 倍吗？
#
#    <small><small>提示：还记得怎么把字符串转换成数字吗？</small></small>

# %%
number_string = input('Number: ')

# %% [markdown]
# 你可以把下面这个列表的第一个和最后一个元素互换吗？

# %%
numbers = [6, 1, 2, 3, 4, 5, 0]

# %% [markdown]
# 你可以写完下面的代码，使得 `numbers` 里面的数都乘以 2，并存到新的列表 `new_numbers` 里面吗？
#
#    <small><small>提示：用 `for` 每一次都往 `new_numbers` 里面加一个元素（怎么加元素来着？）</small></small>

# %%
numbers = [1, 2, 3, 4, 5]
new_numbers = []

# %% [markdown]
# 你可以完成下面的代码，使它输入名字之后，输出 `Hello, (名字)` 吗？

# %%
name = input('Input your name: ')

# %% [markdown]
# 如何做一个永远不结束的死循环？

# %% [markdown]
# 定义一个`year`的变量，判定这一年是什么生肖。

# %% [markdown]
# 写一个函数，带入两个`string`参数，如果两个`string`都有3的倍数长度的字符，则打印`是`。

# %% [markdown]
# 写一个函数，带入两个`string`参数，对于第一个字符串中的每个字母，打印出它在第二个字符串中有没有重复。

# %% [markdown]
# 写一个函数，带入一个`list`参数，求他的平均值。注意不要用`math`module!

# %% [markdown]
# 写一个函数，带入一个`list`参数，并且向用户索要一个`int`，然后判定这个`list`里面有什么元素可以被这个数整除？

# %% [markdown]
# 写一个函数，以一个`string`为参数。创建一个列表。将字符串中的每隔一个字母添加到列表中。从列表中删除最中间的字母。打印这个列表。

# %% [markdown]
# 判定一个音程是小三度还是大三度：https://www.codewars.com/kata/57052ac958b58fbede001616

# %% [markdown]
# 写一个21点游戏，发挥你的想象力！

# %% [markdown]
# 把一个数字转换成二进制，加油！

# %% [markdown]
# 任何CodingBat题目：https://codingbat.com/python

# %% [markdown]
# 写一个`TechX学生`类，写一个初始化程序，赋予这个类你的基本信息（名字，所在课程，年龄，etc.）

# %% [markdown]
# 八皇后：
#
# 在一个8x8的国际象棋棋盘上，皇后不能相互攻击到，即任意两个皇后都不能处于同一行、同一列或同一斜线上。求有多少办法达成这一情况？

# %%
冷知识：为什么Guido van Rossum创造了Python？为什么叫Python？
